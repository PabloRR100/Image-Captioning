# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will use your trained model to generate captions for images in the test dataset.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Get Data Loader for Test Dataset
# - [Step 2](#step2): Load Trained Models
# - [Step 3](#step3): Finish the Sampler
# - [Step 4](#step4): Clean up Captions
# - [Step 5](#step5): Generate Predictions!

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Get Data Loader for Test Dataset
#
# Before running the code cell below, define the transform in `transform_test` that you would like to use to pre-process the test images.
#
# Make sure that the transform that you define here agrees with the transform that you used to pre-process the training images (in **2_Training.ipynb**).  For instance, if you normalized the training images, you should also apply the same normalization procedure to the test images.

# %%
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from torchvision import transforms

# TODO #1: Define a transform to pre-process the testing images.
transform_test = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

#-#-#-# Do NOT modify the code below this line. #-#-#-#

# Create the data loader.
data_loader = get_loader(transform=transform_test,    
                         mode='test')
# Out:
# Vocabulary successfully loaded from vocab.pkl file!

# %% [markdown]
# Run the code cell below to visualize an example test image, before pre-processing is applied.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Obtain sample image before and after pre-processing.
orig_image, image = next(iter(data_loader))

# Visualize sample image, before pre-processing.
plt.imshow(np.squeeze(orig_image))
plt.title('example image')
plt.show()

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Load Trained Models
#
# In the next code cell we define a `device` that you will use move PyTorch tensors to GPU (if CUDA is available).  Run this code cell before continuing.

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Before running the code cell below, complete the following tasks.
#
# ### Task #1
#
# In the next code cell, you will load the trained encoder and decoder from the previous notebook (**2_Training.ipynb**).  To accomplish this, you must specify the names of the saved encoder and decoder files in the `models/` folder (e.g., these names should be `encoder-5.pkl` and `decoder-5.pkl`, if you trained the model for 5 epochs and saved the weights after each epoch).
#
# ### Task #2
#
# Plug in both the embedding size and the size of the hidden layer of the decoder corresponding to the selected pickle file in `decoder_file`.

# %%
# Watch for any changes in model.py, and re-load it automatically.
% load_ext autoreload
% autoreload 2

import os
import torch
from model import EncoderCNN, DecoderRNN

# TODO #2: Specify the saved models to load.
encoder_file = os.path.join('./models', 'encoder-3.pkl')
decoder_file = os.path.join('./models', 'decoder-3.pkl')

# TODO #3: Select appropriate values for the Python variables below.
embed_size = 512
hidden_size = 512

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder, and set each to inference mode.
encoder = EncoderCNN(embed_size)
encoder.eval()
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)
decoder.eval()

# Load the trained weights.
encoder.load_state_dict(torch.load(encoder_file))
decoder.load_state_dict(torch.load(decoder_file))

# Move models to GPU if CUDA is available.
encoder.to(device)
decoder.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 57128437.51it/s]
# DecoderRNN(
#   (embed): Embedding(9955, 512)
#   (lstm): LSTM(512, 512, batch_first=True)
#   (linear): Linear(in_features=512, out_features=9955, bias=True)
#   (dropout): Dropout(p=0.3)
# )

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: Finish the Sampler
#
# Before executing the next code cell, you must write the `sample` method in the `DecoderRNN` class in **model.py**.  This method should accept as input a PyTorch tensor `features` containing the embedded input features corresponding to a single image.
#
# It should return as output a Python list `output`, indicating the predicted sentence.  `output[i]` is a nonnegative integer that identifies the predicted `i`-th token in the sentence.  The correspondence between integers and tokens can be explored by examining either `data_loader.dataset.vocab.word2idx` (or `data_loader.dataset.vocab.idx2word`).
#
# After implementing the `sample` method, run the code cell below.  If the cell returns an assertion error, then please follow the instructions to modify your code before proceeding.  Do **not** modify the code in the cell below.

# %%
# Move image Pytorch Tensor to GPU if CUDA is available.
image = image.to(device)

# Obtain the embedded image features.
features = encoder(image).unsqueeze(1)

# Pass the embedded image features through the model to get a predicted caption.
output = decoder.sample(features)
print('example output:', output)

assert (type(output)==list), "Output needs to be a Python list" 
assert all([type(x)==int for x in output]), "Output should be a list of integers." 
assert all([x in data_loader.dataset.vocab.idx2word for x in output]), "Each entry in the output needs to correspond to an integer that indicates a token in the vocabulary."
# Out:
# example output: [0, 3, 91, 139, 3, 453, 39, 257, 13, 3, 397, 18, 1, 1, 1, 1, 1, 1, 18, 1]

# %% [markdown]
# <a id='step4'></a>
# ## Step 4: Clean up the Captions
#
# In the code cell below, complete the `clean_sentence` function.  It should take a list of integers (corresponding to the variable `output` in **Step 3**) as input and return the corresponding predicted sentence (as a single Python string).

# %%
data_loader.dataset.vocab.idx2word
# Out:
# {0: '<start>',
#  1: '<end>',
#  2: '<unk>',
#  3: 'a',
#  4: 'very',
#  5: 'clean',
#  6: 'and',
#  7: 'well',
#  8: 'decorated',
#  9: 'empty',
#  10: 'bathroom',
#  11: 'panoramic',
#  12: 'view',
#  13: 'of',
#  14: 'kitchen',
#  15: 'all',
#  16: 'its',
#  17: 'appliances',
#  18: '.',
#  19: 'blue',
#  20: 'white',
#  21: 'with',
#  22: 'butterfly',
#  23: 'themed',
#  24: 'wall',
#  25: 'tiles',
#  26: 'photo',
#  27: 'dining',
#  28: 'room',
#  29: 'stop',
#  30: 'sign',
#  31: 'across',
#  32: 'the',
#  33: 'street',
#  34: 'from',
#  35: 'red',
#  36: 'car',
#  37: 'vandalized',
#  38: 'beetle',
#  39: 'on',
#  40: 'road',
#  41: 'border',
#  42: 'butterflies',
#  43: 'paint',
#  44: 'walls',
#  45: 'above',
#  46: 'it',
#  47: 'an',
#  48: 'angled',
#  49: 'beautifully',
#  50: 'two',
#  51: 'people',
#  52: 'are',
#  53: 'walking',
#  54: 'down',
#  55: 'beach',
#  56: 'sink',
#  57: 'toilet',
#  58: 'inside',
#  59: 'small',
#  60: 'black',
#  61: 'square',
#  62: 'tile',
#  63: 'floor',
#  64: 'that',
#  65: 'needs',
#  66: 'repairs',
#  67: 'vanity',
#  68: 'contains',
#  69: 'sinks',
#  70: 'towel',
#  71: 'for',
#  72: 'each',
#  73: 'several',
#  74: 'metal',
#  75: 'balls',
#  76: 'sit',
#  77: 'in',
#  78: 'sand',
#  79: 'near',
#  80: 'group',
#  81: 'carrying',
#  82: 'surf',
#  83: 'boards',
#  84: 'brown',
#  85: 'cabinets',
#  86: ',',
#  87: 'backsplash',
#  88: 'grey',
#  89: 'counters',
#  90: 'surfer',
#  91: 'woman',
#  92: 'child',
#  93: 'walk',
#  94: 'few',
#  95: 'dim',
#  96: 'transportation',
#  97: 'system',
#  98: 'person',
#  99: 'protected',
#  100: 'rain',
#  101: 'by',
#  102: 'their',
#  103: 'umbrella',
#  104: 'walks',
#  105: 'has',
#  106: 'interesting',
#  107: 'women',
#  108: 'preparing',
#  109: 'food',
#  110: 'one',
#  111: 'at',
#  112: 'table',
#  113: 'home',
#  114: 'light',
#  115: 'cat',
#  116: 'stuck',
#  117: 'slightly',
#  118: 'opened',
#  119: 'window',
#  120: 'bicycles',
#  121: 'front',
#  122: 'shop',
#  123: 'green',
#  124: 'tiled',
#  125: 'highlighted',
#  126: 'low',
#  127: 'overhead',
#  128: 'lighting',
#  129: 'bicycle',
#  130: 'is',
#  131: 'parked',
#  132: 'bench',
#  133: 'night',
#  134: 'horse',
#  135: 'grazing',
#  136: 'grass',
#  137: 'house',
#  138: 'someone',
#  139: 'riding',
#  140: 'bike',
#  141: 'pedestal',
#  142: 'located',
#  143: 'poorly',
#  144: 'lit',
#  145: 'this',
#  146: 'pick-up',
#  147: 'game',
#  148: 'shirts',
#  149: 'basketball',
#  150: 'bathtub',
#  151: 'shower',
#  152: 'mirror',
#  153: 'cabinet',
#  154: 'countertop',
#  155: 'includes',
#  156: 'apple',
#  157: 'phone',
#  158: 'teenagers',
#  159: 'surfboards',
#  160: 'his',
#  161: 'to',
#  162: 'indoor',
#  163: 'good',
#  164: 'closeup',
#  165: 'fire',
#  166: 'hydrant',
#  167: 'including',
#  168: 'chains',
#  169: 'man',
#  170: 'standing',
#  171: 'arms',
#  172: 'crossed',
#  173: 'purple',
#  174: 'bus',
#  175: 'dressed',
#  176: 'as',
#  177: 'nun',
#  178: 'tall',
#  179: 'herb',
#  180: 'toaster',
#  181: 'oven',
#  182: 'lady',
#  183: 'purse',
#  184: 'along',
#  185: 'side',
#  186: 'brightly',
#  187: 'colored',
#  188: 'wide',
#  189: 'angle',
#  190: 'work',
#  191: 'area',
#  192: 'around',
#  193: 'many',
#  194: 'silver',
#  195: 'round',
#  196: 'ground',
#  197: 'working',
#  198: 'counter',
#  199: 'illuminated',
#  200: 'sunlight',
#  201: 'granite',
#  202: 'countertops',
#  203: 'skinny',
#  204: 'field',
#  205: 'seagulls',
#  206: 'flying',
#  207: 'while',
#  208: 'trucks',
#  209: 'parking',
#  210: 'lot',
#  211: 'no',
#  212: 'doors',
#  213: 'dishwasher',
#  214: 'refrigerator',
#  215: 'modern',
#  216: 'glass',
#  217: 'pieces',
#  218: 'demonstration',
#  219: 'maintained',
#  220: 'hotel',
#  221: 'making',
#  222: 'angry',
#  223: 'face',
#  224: 'sitting',
#  225: 'motel',
#  226: 'nice',
#  227: 'hood',
#  228: 'city',
#  229: 'sidewalk',
#  230: 'lined',
#  231: 'lamp',
#  232: 'posts',
#  233: 'tv',
#  234: 'public',
#  235: 'restroom',
#  236: 'been',
#  237: 'photographed',
#  238: 'sepia',
#  239: 'old',
#  240: 'styled',
#  241: 'what',
#  242: 'appears',
#  243: 'be',
#  244: 'golden',
#  245: 'gate',
#  246: 'bridge',
#  247: 'peeking',
#  248: 'out',
#  249: 'rolled',
#  250: 'there',
#  251: 'some',
#  252: 'pet',
#  253: 'young',
#  254: 'boy',
#  255: 'surfing',
#  256: 'waves',
#  257: 'top',
#  258: 'covered',
#  259: 'brass',
#  260: 'pots',
#  261: 'pans',
#  262: 'shaving',
#  263: 'her',
#  264: 'wooden',
#  265: 'sky',
#  266: 'full',
#  267: 'colorful',
#  268: 'kites',
#  269: 'mountain',
#  270: 'rides',
#  271: 'river',
#  272: 'stand',
#  273: 'lights',
#  274: 'cupboard',
#  275: 'raft',
#  276: 'atop',
#  277: 'boat',
#  278: 'water',
#  279: 'cars',
#  280: 'trash',
#  281: 'can',
#  282: 'garage',
#  283: 'shorts',
#  284: 'seat',
#  285: 'looking',
#  286: 'jumping',
#  287: 'onto',
#  288: 'folded',
#  289: 'balancing',
#  290: 'image',
#  291: 'children',
#  292: 'paying',
#  293: 'attention',
#  294: 'up',
#  295: 'mill',
#  296: 'about',
#  297: 'background',
#  298: 'compact',
#  299: 'mounted',
#  300: 'roof',
#  301: 'crisp',
#  302: 'neutral',
#  303: 'embellished',
#  304: 'scene',
#  305: 'stainless',
#  306: 'steel',
#  307: 'appliance',
#  308: 'checkered',
#  309: 'pattern',
#  310: 'talking',
#  311: 'self',
#  312: 'portrait',
#  313: 'fancy',
#  314: 'cell',
#  315: 'accessories',
#  316: 'set',
#  317: 'without',
#  318: 'snowy',
#  319: 'skis',
#  320: 'towels',
#  321: 'laid',
#  322: 'stuffed',
#  323: 'animal',
#  324: 'laying',
#  325: 'bed',
#  326: 'sits',
#  327: 'open',
#  328: 'plates',
#  329: 'vegetables',
#  330: 'couple',
#  331: 'toilette',
#  332: 'computer',
#  333: 'taking',
#  334: 'picture',
#  335: 'large',
#  336: 'hours',
#  337: 'eating',
#  338: 'blurry',
#  339: 'rider',
#  340: 'zooms',
#  341: 'past',
#  342: 'new',
#  343: 'mercedes',
#  344: 'skiers',
#  345: 'peak',
#  346: 'thee',
#  347: 'cats',
#  348: 'sleeping',
#  349: 'featuring',
#  350: 'everything',
#  351: 'lies',
#  352: 'smaller',
#  353: 'ball',
#  354: 'board',
#  355: 'playing',
#  356: 'frisbee',
#  357: 'washing',
#  358: 'dishes',
#  359: 'backpack',
#  360: 'holding',
#  361: 'arm',
#  362: 'shoulders',
#  363: 'girl',
#  364: 'next',
#  365: 'him',
#  366: 'three',
#  367: 'owners',
#  368: 'using',
#  369: 'go',
#  370: 'baby',
#  371: 'dog',
#  372: 'clock',
#  373: 'hangs',
#  374: 'multiple',
#  375: 'photos',
#  376: 'extends',
#  377: 'hand',
#  378: 'catch',
#  379: 'silverware',
#  380: 'glasses',
#  381: 'bottle',
#  382: 'wine',
#  383: 'vegetable',
#  384: 'age',
#  385: 'equipment',
#  386: 'kite',
#  387: 'shape',
#  388: 'bottom',
#  389: 'half',
#  390: 'fashioned',
#  391: 'ware',
#  392: 'middle',
#  393: 'croquet',
#  394: 'painted',
#  395: 'does',
#  396: 'trick',
#  397: 'surfboard',
#  398: 'under',
#  399: 'bunch',
#  400: 'strapped',
#  401: 'six',
#  402: 'time',
#  403: 'riders',
#  404: 'goes',
#  405: 'shot',
#  406: 'laundry',
#  407: 'bear',
#  408: "'s",
#  409: 'other',
#  410: 'places',
#  411: 'friend',
#  412: 'seagull',
#  413: 'perches',
#  414: 'van',
#  415: 'parachutes',
#  416: 'fly',
#  417: 'through',
#  418: 'girls',
#  419: 'lunch',
#  420: 'stocked',
#  421: 'supplies',
#  422: 'dish',
#  423: 'chef',
#  424: 'opens',
#  425: 'beside',
#  426: 'island',
#  427: 'random',
#  428: 'being',
#  429: 'prepared',
#  430: 'get',
#  431: 'newly',
#  432: 'family',
#  433: 'dirty',
#  434: 'clothes',
#  435: 'over',
#  436: 'edge',
#  437: 'body',
#  438: 'sun',
#  439: 'sets',
#  440: 'windows',
#  441: 'poses',
#  442: 'hill',
#  443: 'demonstrating',
#  444: 'act',
#  445: 'shelves',
#  446: 'wood',
#  447: 'assorted',
#  448: 'decorations',
#  449: 'plastic',
#  450: 'tarp',
#  451: 'courtyard',
#  452: 'reaches',
#  453: 'wave',
#  454: 'men',
#  455: 'seems',
#  456: 'others',
#  457: 'stairs',
#  458: 'lead',
#  459: 'double',
#  460: 'into',
#  461: 'footed',
#  462: 'tub',
#  463: 'bush',
#  464: 'bumper',
#  465: 'sticker',
#  466: 'word',
#  467: 'buffet',
#  468: 'different',
#  469: 'types',
#  470: 'organized',
#  471: 'closet',
#  472: 'female',
#  473: 'student',
#  474: 'bowls',
#  475: 'microwave',
#  476: 'storefronts',
#  477: 'right',
#  478: 'platform',
#  479: 'silhouette',
#  480: 'sunset',
#  481: 'tent',
#  482: 'stationed',
#  483: 'lane',
#  484: 'bath',
#  485: 'rug',
#  486: 'pile',
#  487: 'bikes',
#  488: 'rack',
#  489: 'outside',
#  490: 'stools',
#  491: 'takes',
#  492: 'selfie',
#  493: 'wrapped',
#  494: 'chain',
#  495: 'evergreen',
#  496: 'sprig',
#  497: 'grazes',
#  498: 'trees',
#  499: 'dogs',
#  500: 'beneath',
#  501: 'owner',
#  502: 'pristine',
#  503: 'waiting',
#  504: 'used',
#  505: 'smiles',
#  506: 'who',
#  507: 'wearing',
#  508: 'together',
#  509: 'enjoying',
#  510: 'company',
#  511: 'crowd',
#  512: 'prepare',
#  513: 'ski',
#  514: 'snow',
#  515: 'slopes',
#  516: 'karaoke',
#  517: 'video',
#  518: 'skiiers',
#  519: 'gathered',
#  520: 'base',
#  521: 'travel',
#  522: 'guy',
#  523: 'building',
#  524: 'another',
#  525: 'shave',
#  526: 'back',
#  527: 'neatly',
#  528: 'stacked',
#  529: 'shelf',
#  530: 'played',
#  531: 'yard',
#  532: 'copper',
#  533: 'pot',
#  534: 'racks',
#  535: 'stove',
#  536: 'restaurant',
#  537: 'filled',
#  538: 'watches',
#  539: 'boys',
#  540: 'play',
#  541: 'singing',
#  542: 'hikers',
#  543: 'climb',
#  544: 'snow-covered',
#  545: 'winter',
#  546: 'clutter',
#  547: 'blocks',
#  548: 'antique',
#  549: 'leaving',
#  550: 'reflection',
#  551: 'guys',
#  552: 'kid',
#  553: 'spa',
#  554: 'like',
#  555: 'shown',
#  556: 'only',
#  557: 'scissors',
#  558: 'loaded',
#  559: 'end',
#  560: 'orange',
#  561: 'gray',
#  562: 'accents',
#  563: 'free-standing',
#  564: 'door',
#  565: 'behind',
#  566: 'corner',
#  567: 'bricks',
#  568: 'lining',
#  569: 'teddy',
#  570: 'dimly',
#  571: 'lying',
#  572: 'bedspread',
#  573: 'mattress',
#  574: 'ocean',
#  575: 'loving',
#  576: 'pose',
#  577: 'cake',
#  578: 'biker',
#  579: 'stands',
#  580: 'legs',
#  581: 'stone',
#  582: 'focus',
#  583: 'shirtless',
#  584: 'pink',
#  585: 'drinking',
#  586: 'dark',
#  587: 'profile',
#  588: 'before',
#  589: 'tops',
#  590: 'individual',
#  591: 'covers',
#  592: 'himself',
#  593: 'rainy',
#  594: 'day',
#  595: 'cleaning',
#  596: 'products',
#  597: 'four',
#  598: 'lawn',
#  599: 'females',
#  600: 'ready',
#  601: 'skate',
#  602: 'cement',
#  603: 'seating',
#  604: 'basket',
#  605: 'yellow',
#  606: 'keyboard',
#  607: 'having',
#  608: 'slice',
#  609: 'bread',
#  610: 'jelly',
#  611: 'crossing',
#  612: 'placed',
#  613: 'passenger',
#  614: 'same',
#  615: 'chairs',
#  616: 'cupboards',
#  617: 'sandy',
#  618: 'mid',
#  619: 'sized',
#  620: 'leaning',
#  621: 'forward',
#  622: 'equipped',
#  623: 'support',
#  624: 'bars',
#  625: 'disabled',
#  626: 'television',
#  627: 'reflected',
#  628: 'off',
#  629: 'nap',
#  630: 'lays',
#  631: 'chest',
#  632: 'attached',
#  633: 'version',
#  634: 'personal',
#  635: 'dual',
#  636: 'wrap',
#  637: 'shadow',
#  638: 'un',
#  639: 'occupied',
#  640: 'allover',
#  641: 'tiling',
#  642: 'wig',
#  643: 'shopping',
#  644: 'center',
#  645: 'containing',
#  646: 'step',
#  647: 'close',
#  648: 'curtain',
#  649: 'he',
#  650: 'falls',
#  651: 'asleep',
#  652: 'flat',
#  653: 'screen',
#  654: 'box',
#  655: 'tissues',
#  656: 'remote',
#  657: 'control',
#  658: 'nearly',
#  659: 'pets',
#  660: 'college',
#  661: 'campus',
#  662: 'splash',
#  663: 'added',
#  664: 'cleaned',
#  665: 'air',
#  666: 'just',
#  667: 'construction',
#  668: 'strip',
#  669: 'single',
#  670: 'teenage',
#  671: 'wire',
#  672: 'against',
#  673: 'surrounded',
#  674: 'handrails',
#  675: 'cards',
#  676: 'parade',
#  677: 'win',
#  678: 'industrial',
#  679: 'ovens',
#  680: 'pictured',
#  681: 'bowl',
#  682: 'separate',
#  683: 'showing',
#  684: 'inspecting',
#  685: 'project',
#  686: 'banquet',
#  687: 'tables',
#  688: 'held',
#  689: 'variety',
#  690: 'meats',
#  691: 'dips',
#  692: 'pastries',
#  693: 'plaza',
#  694: 'stores',
#  695: 'sedan',
#  696: 'cloudy',
#  697: 'microphones',
#  698: 'ages',
#  699: 'skiing',
#  700: 'slope',
#  701: 'gathering',
#  702: 'lighted',
#  703: 'something',
#  704: 'groceries',
#  705: 'race',
#  706: 'busy',
#  707: 'athletes',
#  708: 'appear',
#  709: 'lots',
#  710: 'space',
#  711: 'spiral',
#  712: 'hanging',
#  713: 'chihuahua',
#  714: 'attractive',
#  715: 'couch',
#  716: 'looks',
#  717: 'them',
#  718: 'older',
#  719: 'getting',
#  720: 'lookers',
#  721: 'refridgerator',
#  722: 'friends',
#  723: 'enjoy',
#  724: 'grassy',
#  725: 'fenced',
#  726: 'hooked',
#  727: 'checking',
#  728: 'holds',
#  729: 'leash',
#  730: 'fridge',
#  731: 'halfway',
#  732: 'during',
#  733: 'old-fashioned',
#  734: 'biking',
#  735: 'storefront',
#  736: 'sister',
#  737: 'trying',
#  738: 'high',
#  739: 'items',
#  740: 'shopper',
#  741: 'downtown',
#  742: 'mall',
#  743: 'kids',
#  744: 'master',
#  745: 'bedroom',
#  746: 'oddly',
#  747: 'shaped',
#  748: 'wires',
#  749: 'poles',
#  750: 'hall',
#  751: 'opening',
#  752: 'rooms',
#  753: 'nicely',
#  754: 'metallic',
#  755: 'skateboard',
#  756: 'doing',
#  757: 'technology',
#  758: 'spread',
#  759: 'cocker',
#  760: 'spaniel',
#  761: 'leans',
#  762: 'subway',
#  763: 'court',
#  764: 'below',
#  765: 'flowers',
#  766: 'hits',
#  767: 'big',
#  768: 'spending',
#  769: 'watching',
#  770: 'park',
#  771: 'flowering',
#  772: 'tree',
#  773: 'nearby',
#  774: 'were',
#  775: 'captured',
#  776: 'altered',
#  777: 'serving',
#  778: 'quiet',
#  779: 'adults',
#  780: 'meal',
#  781: 'hallway',
#  782: 'shirt',
#  783: 'jeans',
#  784: 'use',
#  785: 'professional',
#  786: 'laptop',
#  787: 'or',
#  788: 'kind',
#  789: 'spice',
#  790: 'crosswalk',
#  791: 'bags',
#  792: 'hands',
#  793: 'spacious',
#  794: 'cross',
#  795: 'intersection',
#  796: 'skateboarding',
#  797: 'cooking',
#  798: 'paneled',
#  799: 'reflecting',
#  800: 'opposite',
#  801: 'lcd',
#  802: 'panel',
#  803: 'pad',
#  804: 'pretty',
#  805: 'spotless',
#  806: 'bidet',
#  807: 'beautiful',
#  808: 'blonde',
#  809: 'multicolored',
#  810: 'kiosk',
#  811: 'cyclists',
#  812: 'asphalt',
#  813: 'porcelain',
#  814: 'waking',
#  815: 'coat',
#  816: 'wireless',
#  817: 'role',
#  818: 'games',
#  819: 'hat',
#  820: 'traveling',
#  821: 'plate',
#  822: 'armor',
#  823: 'helmet',
#  824: 'reflective',
#  825: 'marble',
#  826: 'rust',
#  827: 'filthy',
#  828: 'alley',
#  829: 'hard',
#  830: 'waits',
#  831: 'frilly',
#  832: 'ramp',
#  833: 'asian',
#  834: 'lounge',
#  835: 'baskets',
#  836: 'goods',
#  837: 'floors',
#  838: 'gentleman',
#  839: 'alongside',
#  840: 'steele',
#  841: 'storage',
#  842: 'skateboarder',
#  843: 'airborne',
#  844: 'banana',
#  845: 'if',
#  846: 'telephone',
#  847: 'receiver',
#  848: 'bicyclists',
#  849: 'underneath',
#  850: 'drying',
#  851: 'modified',
#  852: 'read',
#  853: 'dress',
#  854: 'brushing',
#  855: 'teeth',
#  856: 'highly',
#  857: 'displaying',
#  858: 'train',
#  859: 'station',
#  860: 'made',
#  861: 'living',
#  862: 'toothbrush',
#  863: 'leading',
#  864: 'where',
#  865: 'tires',
#  866: 'examines',
#  867: 'surfers',
#  868: 'ride',
#  869: 'ferry',
#  870: 'vespas',
#  871: 'books',
#  872: 'chair',
#  873: 'store',
#  874: 'doll',
#  875: 'cup',
#  876: 'coffee',
#  877: 'brushes',
#  878: 'bikers',
#  879: 'turn',
#  880: 'fountain',
#  881: 'town',
#  882: 'bicyclist',
#  883: 'wait',
#  884: 'shines',
#  885: 'keys',
#  886: 'lettering',
#  887: 'competing',
#  888: 'handicap',
#  889: 'bar',
#  890: 'natural',
#  891: 'fronted',
#  892: 'combo',
#  893: 'passing',
#  894: 'long',
#  895: 'staring',
#  896: 'facing',
#  897: 'knight',
#  898: 'costume',
#  899: 'motorcycle',
#  900: 'driving',
#  901: 'stack',
#  902: 'beverages',
#  903: 'standup',
#  904: 'male',
#  905: 'dump',
#  906: 'truck',
#  907: 'commercial',
#  908: 'mirrors',
#  909: 'toothbrushes',
#  910: 'pole',
#  911: 'power',
#  912: 'lines',
#  913: 'seats',
#  914: 'blow',
#  915: 'candle',
#  916: 'birthday',
#  917: 'besides',
#  918: 'soccer',
#  919: 'fan',
#  920: 'dressing',
#  921: 'japanese',
#  922: 'displayed',
#  923: 'married',
#  924: 'posing',
#  925: 'piece',
#  926: 'performing',
#  927: 'passes',
#  928: 'shinning',
#  929: 'bright',
#  930: 'entryway',
#  931: 'tricks',
#  932: 'tan',
#  933: 'jacuzzi',
#  934: 'sweater',
#  935: 'inspired',
#  936: 'alone',
#  937: 'locked',
#  938: 'meter',
#  939: 'catches',
#  940: 'but',
#  941: 'fall',
#  942: 'stopped',
#  943: 'downed',
#  944: 'drink',
#  945: 'outfit',
#  946: 'cutout',
#  947: 'sheer',
#  948: 'curtains',
#  949: 'skiis',
#  950: 'tissue',
#  951: 'dispenser',
#  952: 'unused',
#  953: '2',
#  954: 'ceramic',
#  955: 'dinner',
#  956: 'tiny',
#  957: 'little',
#  958: 'reaching',
#  959: 'drawer',
#  960: 'arranged',
#  961: 'display',
#  962: 'decoratively',
#  963: 'resting',
#  964: 'matching',
#  965: 'bathing',
#  966: 'hot',
#  967: 'touches',
#  968: 'royal',
#  969: 'refrigerators',
#  970: 'workstation',
#  971: 'indicate',
#  972: 'have',
#  973: 'gold',
#  974: 'rectangular',
#  975: 'putting',
#  976: 'away',
#  977: 'after',
#  978: 'curtained',
#  979: 'writing',
#  980: 'pretending',
#  981: 'talk',
#  982: 'though',
#  983: 'sports',
#  984: 'going',
#  985: 'smiling',
#  986: 'stucco',
#  987: 'planks',
#  988: 'celebrating',
#  989: 'special',
#  990: 'occasion',
#  991: 'pressed',
#  992: 'lips',
#  993: 'container',
#  994: 'color',
#  995: 'fresh',
#  996: 'airy',
#  997: 'doge',
#  998: 'paws',
#  999: 'overexposed',
#  ...}

# %%
# TODO #4: Complete the function.
def clean_sentence(output):
    new_caption = list()
    for word_id in output:                                  # Iterate over each predicted output
        word = data_loader.dataset.vocab.idx2word[word_id]  # Get the correspondance from our dictionary
        new_caption.append(word)                            # Append the proper word into a list of words of the sentence
        if word == '<end>':                                 # Repear until no more words or the <end> token is found
            break
    new_caption = new_caption[1:-1]                         # Remove <start> and <end> tokens
    sentence = ' '.join(new_caption)                        # Join all the words with a whitespace in between
    return sentence

# %% [markdown]
# After completing the `clean_sentence` function above, run the code cell below.  If the cell returns an assertion error, then please follow the instructions to modify your code before proceeding.

# %%
sentence = clean_sentence(output)
print('example sentence:', sentence)

assert type(sentence)==str, 'Sentence needs to be a Python string!'
# Out:
# example sentence: a woman riding a wave on top of a surfboard .

# %% [markdown]
# # Coment
# ---
# Wow! That was pretty impresive!

# %% [markdown]
# <a id='step5'></a>
# ## Step 5: Generate Predictions!
#
# In the code cell below, we have written a function (`get_prediction`) that you can use to use to loop over images in the test dataset and print your model's predicted caption.

# %%
def get_prediction():
    orig_image, image = next(iter(data_loader))
    plt.imshow(np.squeeze(orig_image))
    plt.title('Sample Image')
    plt.show()
    image = image.to(device)
    features = encoder(image).unsqueeze(1)
    output = decoder.sample(features)    
    sentence = clean_sentence(output)
    print(sentence)

# %% [markdown]
# Run the code cell below (multiple times, if you like!) to test how this function works.

# %%
get_prediction()
# Out:
# a woman sitting on a bench with a dog .

# %% [markdown]
# As the last task in this project, you will loop over the images until you find four image-caption pairs of interest:
# - Two should include image-caption pairs that show instances when the model performed well.
# - Two should highlight image-caption pairs that highlight instances where the model did not perform well.
#
# Use the four code cells below to complete this task.

# %% [markdown]
# ### The model performed well!
#
# Use the next two code cells to loop over captions.  Save the notebook when you encounter two images with relatively accurate captions.

# %%
get_prediction()
# Out:
# a white refrigerator freezer sitting in a kitchen .

# %%
get_prediction()
# Out:
# a bird perched on a branch in a tree .

# %% [markdown]
# ### The model could have performed better ...
#
# Use the next two code cells to loop over captions.  Save the notebook when you encounter two images with relatively inaccurate captions.

# %%
get_prediction()
# Out:
# a bird is flying over a beach with a person on the beach .

# %% [markdown]
# It was actually pretty good prediction. It just saw a bird on it flying. It probably confused it with the waves or some change on the texture of the sky.

# %%
get_prediction()
# Out:
# a large airplane is flying over a bridge .

# %% [markdown]
# It took a while of attemps, but this one is definately inaccurate.
